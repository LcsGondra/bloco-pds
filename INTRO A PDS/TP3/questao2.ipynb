# %% [markdown]
# Gerar dois vetores com 10.000 elementos cada:
#     X1: Distribuição normal com média = 1 e desvio padrão = 0.1.

# %%
import random

import numpy as np

n = 10000
x1 = np.zeros((n))
for i in range(n):
    x1[i] = random.normalvariate(1, 0.1)


print(len(x1))
print(x1)
# Out:
# 10000
# [1.2357156  1.02022977 1.07430462 ... 0.79830496 1.09992046 0.99875384]

# %% [markdown]
# X2: Distribuição uniforme no intervalo [-1,1].

# %%
n = 10000
x2 = np.zeros((n))
for i in range(n):
    x2[i] = random.uniform(-1, 1)


print(len(x2))
print(x2)
# Out:
# 10000
# [ 0.1821228  -0.43695338 -0.00594178 ... -0.86387257 -0.05841235
#  -0.73386461]

# %%
print("media x1", x1.mean())
print("desvio padrao x1", x1.std())

print("media x2", x2.mean())
print("desvio padrao x2", x2.std())
# Out:
# media x1 1.000332575111085
# desvio padrao x1 0.0996452205391151
# media x2 -0.006783156633038638
# desvio padrao x2 0.5724452951548489

# %%
import matplotlib.pyplot as plt

T = np.arange(0, 10000, 1)

plt.subplot(211)
plt.plot(T,x1)
plt.title('normal')
plt.grid()
plt.legend()

plt.subplot(212)
plt.plot(T,x2)
plt.title('uniforme')
plt.grid()
plt.legend()


plt.show()
# Out:
# C:\Users\lucas.gondra\AppData\Local\Temp\ipykernel_10260\2209704839.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\lucas.gondra\AppData\Local\Temp\ipykernel_10260\2209704839.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.hist(x1)
plt.title("Histograma x1")
plt.show()

# %%
plt.hist(x2)
plt.title("Histograma x2")
plt.show()
